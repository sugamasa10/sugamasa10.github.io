# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.normal(50, 10, 1000)
 
plt.hist(x)
# Out:
# (array([  4.,  15.,  54., 182., 256., 275., 129.,  70.,  11.,   4.]),
#  array([14.28944813, 21.42912472, 28.56880131, 35.7084779 , 42.84815448,
#         49.98783107, 57.12750766, 64.26718425, 71.40686083, 78.54653742,
#         85.68621401]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(x, bins=16)
# Out:
# (array([  3.,   1.,  12.,  24.,  52., 111., 140., 168., 189., 128.,  79.,
#          45.,  36.,   7.,   3.,   2.]),
#  array([14.28944813, 18.751746  , 23.21404387, 27.67634173, 32.1386396 ,
#         36.60093747, 41.06323534, 45.5255332 , 49.98783107, 54.45012894,
#         58.9124268 , 63.37472467, 67.83702254, 72.29932041, 76.76161827,
#         81.22391614, 85.68621401]),
#  <BarContainer object of 16 artists>)

# %%
plt.hist(x, bins=16, density=True)
# Out:
# (array([0.0006723 , 0.0002241 , 0.0026892 , 0.00537839, 0.01165319,
#         0.02487508, 0.03137397, 0.03764876, 0.04235486, 0.02868477,
#         0.01770388, 0.01008449, 0.00806759, 0.0015687 , 0.0006723 ,
#         0.0004482 ]),
#  array([14.28944813, 18.751746  , 23.21404387, 27.67634173, 32.1386396 ,
#         36.60093747, 41.06323534, 45.5255332 , 49.98783107, 54.45012894,
#         58.9124268 , 63.37472467, 67.83702254, 72.29932041, 76.76161827,
#         81.22391614, 85.68621401]),
#  <BarContainer object of 16 artists>)

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)
 
plt.scatter(x, y)

# %%
import numpy
import pandas as pd
a = [5, 73, 29, 63, 68, 28, 45, 78, 70, 93]
b = [11, 82, 25, 61, 66, 27, 42, 88, 71, 84]
c = [52, 73, 43, 11, 85, 91, 24, 57, 78, 96]

df = pd.DataFrame([a,b,c]).T
df.corr()
# Out:
#           0         1         2
# 0  1.000000  0.975751  0.296301
# 1  0.975751  1.000000  0.283135
# 2  0.296301  0.283135  1.000000
